# %%
# Install cobrapy library
# !pip install cobra
# Out:
# Requirement already satisfied: cobra in c:\users\coria\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: six in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.15.0)
# Requirement already satisfied: numpy~=1.13 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.18.5)
# Requirement already satisfied: optlang<1.4.6 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.4.4)
# Requirement already satisfied: httpx~=0.14 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (0.17.1)
# Requirement already satisfied: diskcache~=5.0 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (5.2.1)
# Requirement already satisfied: ruamel.yaml~=0.16 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (0.17.2)
# Requirement already satisfied: importlib-resources in c:\users\coria\anaconda3\lib\site-packages (from cobra) (5.1.2)
# Requirement already satisfied: rich~=6.0 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (6.2.0)
# Requirement already satisfied: future in c:\users\coria\anaconda3\lib\site-packages (from cobra) (0.18.2)
# Requirement already satisfied: pydantic~=1.6 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.8.1)
# Requirement already satisfied: pandas~=1.0 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.0.5)
# Requirement already satisfied: swiglpk in c:\users\coria\anaconda3\lib\site-packages (from cobra) (5.0.3)
# Requirement already satisfied: depinfo in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.7.0)
# Requirement already satisfied: appdirs~=1.4 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (1.4.4)
# Requirement already satisfied: python-libsbml==5.19.0 in c:\users\coria\anaconda3\lib\site-packages (from cobra) (5.19.0)
# Requirement already satisfied: sympy>=1.0.0 in c:\users\coria\anaconda3\lib\site-packages (from optlang<1.4.6->cobra) (1.6.1)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\coria\anaconda3\lib\site-packages (from httpx~=0.14->cobra) (1.4.0)
# Requirement already satisfied: sniffio in c:\users\coria\anaconda3\lib\site-packages (from httpx~=0.14->cobra) (1.2.0)
# Requirement already satisfied: httpcore<0.13,>=0.12.1 in c:\users\coria\anaconda3\lib\site-packages (from httpx~=0.14->cobra) (0.12.3)
# Requirement already satisfied: certifi in c:\users\coria\anaconda3\lib\site-packages (from httpx~=0.14->cobra) (2020.6.20)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in c:\users\coria\anaconda3\lib\site-packages (from ruamel.yaml~=0.16->cobra) (0.2.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\coria\anaconda3\lib\site-packages (from rich~=6.0->cobra) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\coria\anaconda3\lib\site-packages (from rich~=6.0->cobra) (2.6.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in c:\users\coria\anaconda3\lib\site-packages (from rich~=6.0->cobra) (0.4.3)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in c:\users\coria\anaconda3\lib\site-packages (from rich~=6.0->cobra) (3.7.4.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\coria\anaconda3\lib\site-packages (from pandas~=1.0->cobra) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\coria\anaconda3\lib\site-packages (from pandas~=1.0->cobra) (2.8.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\coria\anaconda3\lib\site-packages (from sympy>=1.0.0->optlang<1.4.6->cobra) (1.1.0)
# Requirement already satisfied: idna; extra == "idna2008" in c:\users\coria\anaconda3\lib\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra) (2.10)
# Requirement already satisfied: h11==0.* in c:\users\coria\anaconda3\lib\site-packages (from httpcore<0.13,>=0.12.1->httpx~=0.14->cobra) (0.12.0)

# %%
# IMPORT LIBRARIES
import numpy as np
import matplotlib.pyplot as plt
import cobra
from cobra.flux_analysis import flux_variability_analysis
import time
from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)
import pandas as pd
from cue_tools import loadModelURL

# %%
#Models
# E. coli
# iIT341
# iLJ478
# iAF692
# iNF517
# iHN637
# iJB785
# iJN678
# iJN746
# iJR904
# iND750
# iAF987
# iRC1080

link = ['http://bigg.ucsd.edu/static/models/e_coli_core.mat','http://bigg.ucsd.edu/static/models/iIT341.mat',
       'http://bigg.ucsd.edu/static/models/iLJ478.mat','http://bigg.ucsd.edu/static/models/iAF692.mat',
       'http://bigg.ucsd.edu/static/models/iNF517.mat','http://bigg.ucsd.edu/static/models/iHN637.mat',
       'http://bigg.ucsd.edu/static/models/iJB785.mat','http://bigg.ucsd.edu/static/models/iJN678.mat',
       'http://bigg.ucsd.edu/static/models/iJN746.mat','http://bigg.ucsd.edu/static/models/iJR904.mat',
       'http://bigg.ucsd.edu/static/models/iND750.mat','http://bigg.ucsd.edu/static/models/iAF987.mat',
       'http://bigg.ucsd.edu/static/models/iRC1080.mat']
# Number of Models - 7
modelnum = 0
model = loadModelURL(link[modelnum],'mat')
model
# Out:
# <Model e_coli_core at 0x1eebc18f160>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.8739215069684305</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-22.81</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-29.18</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-17.53</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
Summary = model.summary()
UptakeSummary = Summary._display_flux(Summary.uptake_flux, False, 'C', 1e-7)
display(UptakeSummary)
# Out:
#             metabolite     reaction       flux  C-Number   C-Flux
# EX_glc__D_e   glc__D_e  EX_glc__D_e  10.000000         6  100.00%
# EX_nh4_e         nh4_e     EX_nh4_e   4.765319         0    0.00%
# EX_o2_e           o2_e      EX_o2_e  21.799493         0    0.00%
# EX_pi_e           pi_e      EX_pi_e   3.214895         0    0.00%

# %%
model.metabolites.ac_e.formula
# Out:
# 'C2H3O2'

# %%
SecretionSummary = Summary._display_flux(Summary.secretion_flux, False, 'C', 1e-7)
display(SecretionSummary)
# Out:
#          metabolite  reaction       flux  C-Number   C-Flux
# EX_co2_e      co2_e  EX_co2_e -22.809833         1  100.00%
# EX_h2o_e      h2o_e  EX_h2o_e -29.175827         0    0.00%
# EX_h_e          h_e    EX_h_e -17.530865         0    0.00%

# %% [markdown]
# # First Model: "Microbial carbon use efficiency predicted from genome-scale metabolic models" Definition

# %% [markdown]
# ![CUEDefPic.png](attachment:CUEDefPic.png)

# %%
# Finding What Uptake Fluxes Have Metabolites with Carbon

UFC = UptakeSummary[UptakeSummary['C-Number'] > 0].index.values

# Finding What Secretion Fluxes Have Metabolites with Carbon

SFC = SecretionSummary[SecretionSummary['C-Number']>0].index.values

CUE1 = 0
CUE2 = 0
for n in UFC:
    
    CUE1 = CUE1 + UptakeSummary.loc[n,'flux']*UptakeSummary.loc[n,'C-Number']

for n in SFC:
    
    CUE2 = CUE2 + SecretionSummary.loc[n,'flux']*SecretionSummary.loc[n,'C-Number']

# %%
FinalCUE1 = (CUE1 + CUE2)/CUE1
print(FinalCUE1)
# Out:
# 0.18294368848140888

# %% [markdown]
# # Second Model: "Clarifying the interpretation of carbon use efficiency in soil through methods comparison" Definitions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# v1 is the uptake flux of glucose-carbon in the model
#  ΣCO2 is measuring all carbon lost as CO2 by "pyruvate dehydrogenase, gluconate dehydrogenase, 
#  isocitrate dehydrogenase and alpha-ketoglutarate dehydrogenase."  
# Difference in model it limits to focusing only on CO2 exit.

# %%
# Some models do not have glucose influx in their reactions so I will only focus on CO2 output

# %%
for n in SecretionSummary.metabolite.values:
    
    Forms = getattr(model.metabolites,n).formula
    
    if (Forms == 'CO2'):
        
        # Find the location of the flux for Co2
        
        L = SecretionSummary[SecretionSummary['metabolite']==n].index.values
        
        CUE22 = SecretionSummary.loc[L,'flux'].values
        
print(CUE22)
# Out:
# [-0.02420323]

# %%
FinalCUE2 = (CUE1 + CUE22)/CUE1

# %%
print(FinalCUE2)
# Out:
# [0.99691567]

# %% [markdown]
# # Models from "Microbial carbon use efficiency: accounting for population, community, and ecosystem-scale controls over the fate of metabolized organic matter

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# CUEp, P is for population - uses gross biomass divided by subtsrate uptake
# MB (net biomass production)
# CUEc is the first definition, community scale 
# CUEe takes in consideration biomass turnover, do not know if this model has that. But we can just compare it to the biomass
# flux

# %%
# Only doing CUEp because I think it is the only one we can do since CUEc takes into consideration other factors that I am 
# not sure if they are available

# %%
solution = model.optimize()
BiomassProd = solution.objective_value
CUE23 = -CUE2 + BiomassProd
# 
FinalCUE3 = BiomassProd/(CUE23)

# %%
print(FinalCUE3)
print('Captures CUE as how efficient the organism is in producing biomass from its carbon intake - not net usage')
# Out:
# 0.006605699288021379
# Captures CUE as how efficient the organism is in producing biomass from its carbon intake - not net usage

# %% [markdown]
# # Model from Paper "Evaluating soil microbial carbon use efficiency explicitlyas a function of cellular processes: implications for measurements and models"

# %%
# This one is a slight variation of the one above but instead of total C secretred it only takes CO2 into consideration and biomass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
FinalCUE4 = (BiomassProd)/(BiomassProd - CUE22)
print(FinalCUE4)
# Out:
# [0.63788132]

# %%
FinalCUETab = pd.DataFrame(np.array([[FinalCUE1],[FinalCUE2],[FinalCUE3],[FinalCUE4]]), columns = ['CUE'],index = ['Def 1','Def 2','Def 3','Def 4'])

# %%
FinalCUETab
# Out:
#                         CUE
# Def 1              0.182944
# Def 2  [0.9969156746928791]
# Def 3             0.0066057
# Def 4  [0.6378813154835061]
